# %% [markdown]
# # Addiction Research

# %%
import pandas as pd
import numpy as np

# ipynb dependencies
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings('ignore')

# viz dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go

# %% [markdown]
# # 10 Most Common Addictions in the United States
#
# According to https://www.addictioncenter.com/addiction/10-most-common-addictions/
#
# 1) Tobacco (nicotine) – Over 40 Million
# <br>
# 2) Alcohol – 18 Million
# <br>
# 3) Marijuana – 4.2 Million
# <br>
# 4) Benzodiazepines – 400,000
# <br>
# 5) Stimulants – 329,000
# <br>
# 6) Inhalants – 140,000
# <br>
# 7) Sedatives (barbiturates) – 78,000
# <br>
# 8) Painkillers – 1.8 Million
# <br>
# 9) Cocaine – 821,000
# <br>
# 10) Heroin – 426,000

# %% [markdown]
# According to https://www.drugabuse.gov/publications/principles-drug-addiction-treatment-research-based-guide-third-edition/frequently-asked-questions/drug-addiction-treatment-worth-its-cost
# <br>
# <i>"Substance abuse costs our Nation over <b>600 billion USD annually</b> and treatment can help reduce these costs. <b>Drug addiction treatment has been shown to reduce associated  health and social costs by far more than the cost of the treatment itself.</b> Treatment is also much less expensive than its alternatives, such as incarcerating addicted persons. For example, the average cost for 1 full year of methadone maintenance treatment is approximately 4,700 USD per patient, whereas 1 full year of imprisonment costs approximately 24,000 USD per person."</i>

# %% [markdown]
# ## Exploration of the Federal Drug Control Spending by Function FY2013-FY2018 <br>(Budget Authority in Millions of US Dollars)

# %%
df = pd.read_excel('addiction_data.xlsx')
df.shape
df
# Out:
# (11, 7)
#                           Function  FY 2013 Final  FY 2014 Final  \
# 0                        Treatment       7888.600       9481.800
# 1               Percent-Treatement          0.313          0.369
# 2                       Prevention       1274.900       1316.900
# 3               Percent-Prevention          0.051          0.051
# 4         Domestic Law Enforcement       8850.000       9348.800
# 5   Percent-DomesticLawInforcement          0.351          0.363
# 6                     Interdiction       3940.600       3948.500
# 7             Percent-Interdiction          0.156          0.153
# 8                    International       1848.500       1637.100
# 9            Percent-International          0.073          0.064
# 10                           Total      23800.400      25724.900
#
#     FY 2015 Final  FY 2016 Final  FY 2017 CR  FY 2018 Requested
# 0        9553.100       9845.100   10580.800          10783.400
# ...

# %%
df.set_index('Function', inplace=True)

# %%
df
# Out:
#                                 FY 2013 Final  FY 2014 Final  FY 2015 Final  \
# Function
# Treatment                            7888.600       9481.800       9553.100
# Percent-Treatement                      0.313          0.369          0.369
# Prevention                           1274.900       1316.900       1341.500
# Percent-Prevention                      0.051          0.051          0.052
# Domestic Law Enforcement             8850.000       9348.800       9394.500
# Percent-DomesticLawInforcement          0.351          0.363          0.363
# Interdiction                         3940.600       3948.500       3960.900
# Percent-Interdiction                    0.156          0.153          0.153
# International                        1848.500       1637.100       1643.000
# Percent-International                   0.073          0.064          0.063
# Total                               23800.400      25724.900      25893.000
#
# ...

# %% [markdown]
# # Money Spent on Treatment through the years

# %%
x=df.columns.values.tolist()
x
y=df[:1].values.tolist()
y
# Out:
# ['FY 2013 Final',
#  'FY 2014 Final',
#  'FY 2015 Final',
#  'FY 2016 Final',
#  'FY 2017 CR',
#  'FY 2018 Requested']
# [[7888.6, 9481.8, 9553.1, 9845.1, 10580.8, 10783.4]]

# %%
y=[7888.6, 9481.8, 9553.1, 9845.1, 10580.8, 10783.4]

# %%
# width = 1/1.5
# plt.bar(x,y,width, color='blue')
# fig=plt.gcf()
# plot_url=py.plot(fig,filename='treatments')

# %%
# data = [go.Bar(x=x,y=y)]
# py.iplot(data,filename='treatment')

# %% [markdown]
# ![ ](images/1.png)
# ![ ](images/2.png)
# ![ ](images/3.png)

# %% [markdown]
# ![](/images/1.png)
# ![](/images/2.png)
# ![](/images/3.png)
